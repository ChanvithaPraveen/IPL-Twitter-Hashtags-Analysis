# %%
import pandas as pd

df1 = pd.read_csv('df1_cleaned_final.csv')
df1
# Out:
#                          user_name  \
# 0                 gaurav dhanawat
# 1                      शुभम दोहरे
# 2                    steven gordon
# 3                    bhumish patel
# 4                      kunal bhoir
# ...                            ...
# 416736              kushal panchal
# 416737  ntr- vk- rcb - thalapathy
# 416738                 iknowfactso
# 416739               vivo ipl 2020
# 416740                k.ponaravind
#
#                                          user_description  user_followers  \
# 0       live evs operator/coordinator | ex ten sports ...             147
# 1       %bhopali b+ proud to be an #indian i love #ind...             113
# 2       buns are good but puns are better, best served...              27
# 3       student at concordia university, montreal, ca ...             131
# 4       being fake is a new trend..and everyone seems ...              33
# ...                                                   ...             ...
# ...

# %%
# Assuming you have a DataFrame df with columns day, month, and year
df1['datetime'] = pd.to_datetime(df1[['year', 'month', 'day']], format='%Y-%m-%d')

# %%
df1
# Out:
#                          user_name  \
# 0                 gaurav dhanawat
# 1                      शुभम दोहरे
# 2                    steven gordon
# 3                    bhumish patel
# 4                      kunal bhoir
# ...                            ...
# 416736              kushal panchal
# 416737  ntr- vk- rcb - thalapathy
# 416738                 iknowfactso
# 416739               vivo ipl 2020
# 416740                k.ponaravind
#
#                                          user_description  user_followers  \
# 0       live evs operator/coordinator | ex ten sports ...             147
# 1       %bhopali b+ proud to be an #indian i love #ind...             113
# 2       buns are good but puns are better, best served...              27
# 3       student at concordia university, montreal, ca ...             131
# 4       being fake is a new trend..and everyone seems ...              33
# ...                                                   ...             ...
# ...

# %%
df1.to_csv('with_datetime.csv')
